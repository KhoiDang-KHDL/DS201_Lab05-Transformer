# %%
# !git clone https://github.com/KhoiDang-KHDL/DS201_Lab05-Transformer
# Out:
# Cloning into 'DS201_Lab05-Transformer'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 21 (delta 7), reused 11 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (21/21), 12.35 KiB | 2.47 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# !pip install pyvi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 64.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 42.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Bài 1

# %%
# %cd /kaggle/working/DS201_Lab05-Transformer/Bai_1
# Out:
# /kaggle/working/DS201_Lab05-Transformer/Bai_1

# %%
# !python main.py
# Out:
# 16:57:46 - INFO - Using device: cuda
# 16:57:46 - INFO - Model Config: d_model=256, layers=2, heads=4
# 16:57:46 - INFO - Building Vocabulary...
# 16:57:48 - INFO - Vocab Size: 3140 tokens
# 16:57:48 - INFO - Labels (4): {'app': 0, 'cosmetic': 1, 'fashion': 2, 'mobile': 3}
# 16:57:51 - INFO - Loaded 4350 samples from /kaggle/input/uit-viocd/UIT-ViOCD/train.json. Skipped 37 short/empty samples.
# 16:57:51 - INFO - Loaded 545 samples from /kaggle/input/uit-viocd/UIT-ViOCD/dev.json. Skipped 3 short/empty samples.
# 16:57:51 - INFO - Initializing Transformer Model (Base)...
# 16:57:55 - INFO - Start Training...
# 16:58:02 - INFO - Epoch 1/30 | Train Loss: 1.3445 | Val Loss: 1.1014 | Acc: 0.3083 | F1: 0.2530 [BEST MODEL SAVED]
# 16:58:08 - INFO - Epoch 2/30 | Train Loss: 1.1915 | Val Loss: 1.0175 | Acc: 0.3523 | F1: 0.2939 [BEST MODEL SAVED]
# 16:58:13 - INFO - Epoch 3/30 | Train Loss: 1.1052 | Val Loss: 0.8840 | Acc: 0.4532 | F1: 0.3718 [BEST MODEL SAVED]
# ...

# %% [markdown]
# # Bài 2

# %%
# %cd /kaggle/working/DS201_Lab05-Transformer/Bai_2
# Out:
# /kaggle/working/DS201_Lab05-Transformer/Bai_2

# %%
# !python main.py
# Out:
# 17:00:52 - INFO - Using device: cuda
# 17:00:52 - INFO - Building Vocabulary...
# Building vocab from: /kaggle/input/phoner/PhoNER/train_word.json
# File JsonL
# Vocab size: 4741
# Num tags: 20
# 17:00:52 - INFO - Vocab Size: 4741
# 17:00:52 - INFO - Tags (20): {'B-AGE': 0, 'B-DATE': 1, 'B-GENDER': 2, 'B-JOB': 3, 'B-LOCATION': 4, 'B-NAME': 5, 'B-ORGANIZATION': 6, 'B-PATIENT_ID': 7, 'B-SYMPTOM_AND_DISEASE': 8, 'B-TRANSPORTATION': 9, 'I-AGE': 10, 'I-DATE': 11, 'I-JOB': 12, 'I-LOCATION': 13, 'I-NAME': 14, 'I-ORGANIZATION': 15, 'I-PATIENT_ID': 16, 'I-SYMPTOM_AND_DISEASE': 17, 'I-TRANSPORTATION': 18, 'O': 19, '<pad_tag>': -100}
# Loading data from: /kaggle/input/phoner/PhoNER/train_word.json
# File JsonL
# Loading data from: /kaggle/input/phoner/PhoNER/dev_word.json
# File JsonL
# 17:00:53 - INFO - Initializing Transformer Model for NER...
# 17:00:54 - INFO - Start Training...
# 17:00:57 - INFO - Epoch 1/15 | Train Loss: 1.0019 | Val Loss: 0.5210 | Acc: 0.8416 | F1: 0.8267 [BEST SAVED]
# ...
